# %% [markdown]
# # Notes
#
# This exercise covers the following topics:
#
# - Variables
# - Operators
# - Conditional Statements
# - Lists
# - Dictionaries
# - Loops

# %% [markdown]
# # Questions
#
# 1. Write a Python program that:
#     * Stores your name, age and height in variables.
#     * Prints them in a sentence like:
#    `My name is John, I am 20 years old and 5.9 feet tall.`

# %%
Name = "Oluwafemi"
Age = "32"
Height = "5"   #unit in feett

# %% [markdown]
# 2. Write a program that:
#    * Uses values of two declared variables to:
#    * Perform:
#      - Addition
#      - Subtraction
#      - Multiplication
#      - Division
#     * Prints the results.

# %%
First_num = 4
Second_num = 5
Add = First_num + Second_num 
Sub = First_num - Second_num
Multi = First_num * Second_num
Divi = First_num / Second_num

print (f'The addition of {First_num} and {Second_num} is {Add}.')
print (f'If you subtract {First_num} from {Second_num}, then you have {Sub}.')
print (f'If you multiply {First_num} by {Second_num}, then you have {Multi}.')
print (f'If you divide {First_num} by {Second_num}, then you have {Divi}.')
# Out:
# The addition of 4 and 5 is 9.
# If you subtract 4 from 5, then you have -1.
# If you multiply 4 by 5, then you have 20.
# If you divide 4 by 5, then you have 0.8.

# %% [markdown]
# 3. Write a program that:
#    * Takes the value of a decalred variable.
#    * Checks whether it is even or odd.
#    * Prints the result.

# %%
num = 4
if num % 2 == 0:
    print (f'{num} is an even number')
else:
     print (f'{num} is an odd number')
# Out:
# 4 is an even number

# %% [markdown]
# 4. Write a program that:
#    * takes the score of a student (declared)
#    * Assigns grades:
#      - 70-100 : A
#      - 60-69 : B
#      - 50-59 : C
#      - 45-49 : D
#      - 0-44 : E
#     * Prints the grade

# %%
student_score = 45
if student_score >= 70 and student_score <= 100 :
    print ("Your grade is 'A'")
elif student_score >= 60 and student_score <= 69 :
    print ("Your grade is 'B'")
elif student_score >= 50 and student_score <= 59 :
    print ("Your grade is 'C'")
elif student_score >= 45 and student_score <= 49 :
    print ("Your grade is 'D'")
else:
    print ("Your grade is 'E'")
# Out:
# Your grade is 'D'

# %% [markdown]
# 5. Create a list of 5 favorite foods:
#    * Print the list.
#    * Add one more food.
#    * Remove one food, different from the one you added.
#    * Print the updated list.

# %%
F_food = ['Rice', 'Beans', 'Spagetti', 'Wheat', 'Plantain']
F_food.append('Semo') #to add new food to the end of the list
F_food.insert(3, 'Poundoyam') #to add new food to a precise location
F_food # this print the new list after the addition of new foods
F_food.remove('Beans')
F_food #print the new list after removing a food
# Out:
# ['Rice', 'Spagetti', 'Poundoyam', 'Wheat', 'Plantain', 'Semo']

# %% [markdown]
# 6. Write a program that:
#    * Uses a loop to calculate the sum of numbers from 1 to 50
#    * Prints the result.

# %%
sum = 0
x = 0
while x <= 50:
    sum = sum + x
    x = x + 1
print (f'The sum of numbers from 1 to 50 is "{sum}"')
# Out:
# The sum of numbers from 1 to 50 is "1275"

# %% [markdown]
# ## Bonus Question (Optional)
#
# Write a Python script to find out what jobs you are qualified based on a set of skills. The script will evaluate a list of job roles, each associated with its own set of required skills, against the skills you have. Determine which roles you're potentially qualified for and print out these roles. If there are no roles that match your skills, print a message saying there are no matching job roles based on the provided skills.ou have

# %% [markdown]
# There are some pre-defined variables that you will be using:
#
# 1. `job_roles`: list of dictionaries, where each dictionary represents a different job role within data science. Each dictionary has the key-value pairs:
#     * `role`: Name of the job role
#     * `skills`: A list of strings, each representing a skill required for the job
# 2. `my_skills`: A list of strings, representing the skills you have

# %%
# Define data science job roles and required skills
job_roles = [
    {'role': 'Data Analyst', 'skills': ['Python', 'SQL', 'Excel']},
    {'role': 'Data Scientist', 'skills': ['Python', 'R', 'Machine Learning', 'Deep Learning']},
    {'role': 'Machine Learning Engineer', 'skills': ['Python', 'TensorFlow', 'PyTorch', 'Scikit-Learn']},
    {'role': 'Data Engineer', 'skills': ['Python', 'Apache Spark', 'Hadoop', 'SQL']},
    {'role': 'Business Intelligence Analyst', 'skills': ['Python', 'SQL', 'Tableau', 'Power BI', 'Excel']},
    {'role': 'Quantitative Analyst', 'skills': ['R', 'Python', 'MATLAB', 'Statistics']},
    {'role': 'Operations Analyst', 'skills': ['Python', 'SQL', 'Data Visualization', 'Process Improvement']},
    {'role': 'Database Administrator', 'skills': ['SQL', 'Oracle', 'MySQL', 'Database Management']},
    {'role': 'AI Engineer', 'skills': ['Python', 'TensorFlow', 'PyTorch', 'Computer Vision']},
    {'role': 'Statistician', 'skills': ['R', 'SAS', 'Python', 'Statistical Modeling']}
]
# My skills
my_skills = ['Python', 'SQL', 'Excel']
qualified_roles = [] #storage for qualified roles

# Check qualification for each role
for job in job_roles:
    required_skills = job['skills']
    if all(skill in my_skills for skill in required_skills):
        qualified_roles.append(job['role'])

# Print results
if qualified_roles:
    print("You are qualified for the following roles:")
    for role in qualified_roles:
        print(f'  - {role}')
else:
    print("There are no matching job roles based on the provided skills.")
# Out:
# You are qualified for the following roles:
#   - Data Analyst

# %% [markdown]
# **Pointer**: Iterate through each job role in job_roles and determine whether or not you have the required skills. Get the roles you are qualified for in a list.
#
# **Notes**:
#
# * Create an empty list where we will put the roles we qualify for `qualified_roles`.
# * Use a `for` loop to go through the jobs.
# * Nested `for` loop to look through the skills for each role.
# * An `if` statement checks if the skill in the role is in the list of skills provided.
# * If it's true then add that role to the `qualified_roles` list we created.
